# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df=pd.read_csv(r"D:\CTTC\Project\Social_Media_Analysis.csv")
df.head()
# Out:
#    Student_ID  Age  Gender Academic_Level     Country  Avg_Daily_Usage_Hours  \
# 0           1   19  Female  Undergraduate  Bangladesh                    5.2
# 1           2   22    Male       Graduate       India                    2.1
# 2           3   20  Female  Undergraduate         USA                    6.0
# 3           4   18    Male    High School          UK                    3.0
# 4           5   21    Male       Graduate      Canada                    4.5
#
#   Most_Used_Platform Affects_Academic_Performance  Sleep_Hours_Per_Night  \
# 0          Instagram                          Yes                    6.5
# 1                  X                           No                    7.5
# 2           Whatsapp                          Yes                    5.0
# 3            YouTube                           No                    7.0
# 4           Facebook                          Yes                    6.0
#
#    Mental_Health_Score  ... Addicted_Score  Purpose of Use  \
# ...

# %%
df.isnull().sum()
# Out:
# Student_ID                      0
# Age                             0
# Gender                          0
# Academic_Level                  0
# Country                         0
# Avg_Daily_Usage_Hours           0
# Most_Used_Platform              0
# Affects_Academic_Performance    0
# Sleep_Hours_Per_Night           0
# Mental_Health_Score             0
# Relationship_Status             0
# Conflicts_Over_Social_Media     0
# Addicted_Score                  0
# Purpose of Use                  0
# Number of Platforms Used        0
# Device Used Most                0
# Parental Monitoring             0
# Academic Performance            0
# Daily Study Hours               0
# Year of Study                   0
# Region                          0
# Year_Of_Admission               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1605 entries, 0 to 1604
# Data columns (total 22 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Student_ID                    1605 non-null   int64
#  1   Age                           1605 non-null   int64
#  2   Gender                        1605 non-null   object
#  3   Academic_Level                1605 non-null   object
#  4   Country                       1605 non-null   object
#  5   Avg_Daily_Usage_Hours         1605 non-null   float64
#  6   Most_Used_Platform            1605 non-null   object
#  7   Affects_Academic_Performance  1605 non-null   object
#  8   Sleep_Hours_Per_Night         1605 non-null   float64
#  9   Mental_Health_Score           1605 non-null   int64
#  10  Relationship_Status           1605 non-null   object
#  11  Conflicts_Over_Social_Media   1605 non-null   int64
# ...

# %%
df.head()
# Out:
#    Student_ID  Age  Gender Academic_Level     Country  Avg_Daily_Usage_Hours  \
# 0           1   19  Female  Undergraduate  Bangladesh                    5.2
# 1           2   22    Male       Graduate       India                    2.1
# 2           3   20  Female  Undergraduate         USA                    6.0
# 3           4   18    Male    High School          UK                    3.0
# 4           5   21    Male       Graduate      Canada                    4.5
#
#   Most_Used_Platform Affects_Academic_Performance  Sleep_Hours_Per_Night  \
# 0          Instagram                          Yes                    6.5
# 1                  X                           No                    7.5
# 2           Whatsapp                          Yes                    5.0
# 3            YouTube                           No                    7.0
# 4           Facebook                          Yes                    6.0
#
#    Mental_Health_Score  ... Addicted_Score  Purpose of Use  \
# ...

# %%
for i in df.columns:
    print(i,':',"\n",df[i].unique())
# Out:
# Student_ID :
#  [   1    2    3 ... 1603 1604 1605]
# Age :
#  [19 22 20 18 21 23 24]
# Gender :
#  ['Female' 'Male']
# Academic_Level :
#  ['Undergraduate' 'Graduate' 'High School']
# Country :
#  ['Bangladesh' 'India' 'USA' 'UK' 'Canada' 'Australia' 'Germany' 'Brazil'
#  'Japan' 'South Korea' 'France' 'Spain' 'Italy' 'Mexico' 'Russia' 'China'
#  'Sweden' 'Norway' 'Denmark' 'Netherlands' 'Belgium' 'Switzerland'
#  'Austria' 'Portugal' 'Greece' 'Ireland' 'New Zealand' 'Singapore'
#  'Malaysia' 'Thailand' 'Vietnam' 'Philippines' 'Indonesia' 'Taiwan'
#  'Hong Kong' 'Turkey' 'Israel' 'UAE' 'Egypt' 'Morocco' 'South Africa'
#  'Nigeria' 'Kenya' 'Ghana' 'Argentina' 'Chile' 'Colombia' 'Peru'
#  'Venezuela' 'Ecuador' 'Uruguay' 'Paraguay' 'Bolivia' 'Costa Rica'
#  'Panama' 'Jamaica' 'Trinidad' 'Bahamas' 'Iceland' 'Finland' 'Poland'
#  'Romania' 'Hungary' 'Czech Republic' 'Slovakia' 'Croatia' 'Serbia'
#  'Slovenia' 'Bulgaria' 'Estonia' 'Latvia' 'Lithuania' 'Ukraine' 'Moldova'
# ...

# %%
df.columns = df.columns.str.strip().str.replace(' ', '_').str.replace('-', '_')

text_columns = ['Gender', 'Academic_Level', 'Country', 'Most_Used_Platform',
                'Affects_Academic_Performance', 'Relationship_Status',
                'Purpose_of_Use', 'Device_Used_Most', 'Parental_Monitoring',
                'Academic_Performance', 'Year_of_Study', 'Region']

# %%
df[text_columns] = df[text_columns].apply(lambda x: x.str.strip().str.title())

# %%
df.columns.tolist()
# Out:
# ['Student_ID',
#  'Age',
#  'Gender',
#  'Academic_Level',
#  'Country',
#  'Avg_Daily_Usage_Hours',
#  'Most_Used_Platform',
#  'Affects_Academic_Performance',
#  'Sleep_Hours_Per_Night',
#  'Mental_Health_Score',
#  'Relationship_Status',
#  'Conflicts_Over_Social_Media',
#  'Addicted_Score',
#  'Purpose_of_Use',
#  'Number_of_Platforms_Used',
#  'Device_Used_Most',
#  'Parental_Monitoring',
#  'Academic_Performance',
#  'Daily_Study_Hours',
#  'Year_of_Study',
#  'Region',
#  'Year_Of_Admission']

# %%
# Gender Distribution
sns.countplot(x=df['Gender'],hue=df['Academic_Level'])
plt.title("count Plot")
plt.show()

# %%
# Age Distribution
sns.distplot(df['Age'][df['Academic_Level']=='Undergraduate'],label='Undergraduate', color='green')
plt.legend()
sns.distplot(df['Age'][df['Academic_Level']=='Graduate'],label='Graduate', color='yellow')
plt.legend()
sns.distplot(df['Age'][df['Academic_Level']=='High School'],label='High School', color='orange')
plt.legend()
plt.show()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_2584\362511551.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'][df['Academic_Level']=='Undergraduate'],label='Undergraduate', color='green')
# C:\Users\Hp\AppData\Local\Temp\ipykernel_2584\362511551.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
# Boxplot - Daily Usage vs Academic Performance
sns.boxplot(data=df, x='Academic_Performance', y='Avg_Daily_Usage_Hours', palette='coolwarm')
plt.title('Avg Daily Usage vs Academic Performance')
plt.show()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_2584\803459140.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Academic_Performance', y='Avg_Daily_Usage_Hours', palette='coolwarm')

# %%
# Boxen plot
sns.boxenplot(x = df['Academic_Performance'],y=df['Avg_Daily_Usage_Hours'], hue=df['Academic_Performance'])
plt.title('Boxen Plot')
plt.show()

# %%
# swarm plot
sns.swarmplot(x = df['Academic_Performance'],y=df['Avg_Daily_Usage_Hours'], hue=df['Academic_Performance'])
plt.title('Swarm Plot')
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 18.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 24.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 14.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 24.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
# Correlation Heatmap
plt.figure()
score_cols = ['Addicted_Score', 'Mental_Health_Score', 'Conflicts_Over_Social_Media',
              'Daily_Study_Hours', 'Avg_Daily_Usage_Hours', 'Sleep_Hours_Per_Night']
corr = df[score_cols].corr()
sns.heatmap(corr, annot=True, cmap='viridis', linewidths=0.5)
plt.title('Correlation between Behavioral Metrics')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Most_Used_Platform', order=df['Most_Used_Platform'].value_counts().index, palette='Set2')
plt.title('Most Used Social Media Platforms')
plt.xlabel('Platform')
plt.ylabel('Number of Students')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_2584\2449510975.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Most_Used_Platform', order=df['Most_Used_Platform'].value_counts().index, palette='Set2')

# %%
sns.pairplot(df,hue = 'Academic_Performance')
plt.show()

# %%
df.drop(columns=["Country", "Relationship_Status", "Year_of_Study","Most_Used_Platform", "Affects_Academic_Performance","Purpose_of_Use"], inplace=True, errors='ignore')

# %%
for i in df.columns:
    print(i,':',"\n",df[i].unique())
# Out:
# Student_ID :
#  [   1    2    3 ... 1603 1604 1605]
# Age :
#  [19 22 20 18 21 23 24]
# Gender :
#  ['Female' 'Male']
# Academic_Level :
#  ['Undergraduate' 'Graduate' 'High School']
# Avg_Daily_Usage_Hours :
#  [5.2 2.1 6.  3.  4.5 7.2 1.5 5.8 4.  3.3 4.8 5.5 2.8 6.5 3.7 4.2 2.  5.
#  3.5 4.7 5.3 2.5 4.9 5.7 3.2 6.1 3.8 4.4 2.2 5.9 3.6 5.4 2.6 5.6 3.1 6.2
#  3.9 2.3 4.6 2.7 6.3 2.4 2.9 5.1 4.3 4.1 3.4 6.4 7.  6.8 6.9 6.7 6.6 7.1
#  7.3 7.4 7.5 7.6 7.7 7.8 7.9 8.  8.1 8.2 8.3 8.4 8.5]
# Sleep_Hours_Per_Night :
#  [6.5 7.5 5.  7.  6.  4.5 8.  6.2 5.8 7.2 5.5 6.8 7.8 5.7 6.7 5.9 7.3 5.4
#  6.9 5.2 6.6 7.4 5.3 5.1 7.1 5.6 6.4 6.3 6.1 7.6 7.7 7.9 8.1 8.2 8.3 4.9
#  8.4 4.8 8.5 4.7 8.6 4.6 4.4 8.7 4.3 8.8 4.2 8.9 4.1 9.  9.1 9.2 9.3 9.4
#  4.  9.5 3.9 9.6 3.8]
# Mental_Health_Score :
#  [6 8 5 7 4 9]
# Conflicts_Over_Social_Media :
#  [3 0 4 1 2 5]
# Addicted_Score :
#  [8 3 9 4 7 2 5 6]
# Number_of_Platforms_Used :
#  [5 1 4 3 2]
# Device_Used_Most :
# ...

# %%
df.dtypes
# Out:
# Student_ID                       int64
# Age                              int64
# Gender                          object
# Academic_Level                  object
# Avg_Daily_Usage_Hours          float64
# Sleep_Hours_Per_Night          float64
# Mental_Health_Score              int64
# Conflicts_Over_Social_Media      int64
# Addicted_Score                   int64
# Number_of_Platforms_Used         int64
# Device_Used_Most                object
# Parental_Monitoring             object
# Academic_Performance            object
# Daily_Study_Hours                int64
# Region                          object
# Year_Of_Admission                int64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df.Academic_Level = le.fit_transform(df.Academic_Level)

# %%
df.Academic_Level.unique()
# Out:
# array([2, 0, 1])

# %%
le.inverse_transform([2, 0, 1])
# Out:
# array(['Undergraduate', 'Graduate', 'High School'], dtype=object)

# %%
le1 = LabelEncoder()
df.Academic_Performance = le1.fit_transform(df.Academic_Performance)

# %%
df.Academic_Performance.unique()
# Out:
# array([0, 1, 2, 3])

# %%
le1.inverse_transform([0, 1, 2, 3])
# Out:
# array(['Average', 'Excellent', 'Good', 'Poor'], dtype=object)

# %%
le2 = LabelEncoder()
df.Region = le2.fit_transform(df.Region)

# %%
df.Region.unique()
# Out:
# array([1, 2, 3, 4, 0])

# %%
le2.inverse_transform([1, 2, 3, 4, 0])
# Out:
# array(['East', 'North', 'South', 'West', 'Central'], dtype=object)

# %%
le3 = LabelEncoder()
df.Gender = le3.fit_transform(df.Gender)

# %%
df.Gender.unique()
# Out:
# array([0, 1])

# %%
le3.inverse_transform([0, 1])
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
le4 = LabelEncoder()
df.Parental_Monitoring = le4.fit_transform(df.Parental_Monitoring)

# %%
df.Parental_Monitoring.unique()
# Out:
# array([1, 0, 2])

# %%
le4.inverse_transform([1, 0, 2])
# Out:
# array(['Sometimes', 'No', 'Yes'], dtype=object)

# %%
le5 = LabelEncoder()
df.Device_Used_Most = le5.fit_transform(df.Device_Used_Most)

# %%
df.Device_Used_Most.unique()
# Out:
# array([2, 1, 0, 3])

# %%
le5.inverse_transform([2, 1, 0, 3])
# Out:
# array(['Mobile', 'Laptop', 'Desktop', 'Tablet'], dtype=object)

# %%
plt.figure(figsize=(14,10))
c = df.corr()
sns.heatmap(c, annot = True)
plt.title('Heatmap')
plt.show()

# %%
ip = df.drop(['Student_ID', 'Academic_Performance'], axis=1)
op = df['Academic_Performance']

# %%
# Train test Split
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(ip,op, test_size=0.2)

# %%
# Standard Scaler
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
x_train = sc.fit_transform(x_train)  # Fit only on training data
x_test = sc.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y1 = lr.predict(x_test)

# %%
from sklearn.metrics import f1_score, recall_score, precision_score, accuracy_score
acc = accuracy_score(y1, y_test)
f1 = f1_score(y1, y_test, average='weighted')
pre = precision_score(y1, y_test, average='weighted')
rel = recall_score(y1, y_test, average='weighted')
print('Accuracy:', acc)
print('F1 Score:', f1)
print('Precision:', pre)
print('Recall:', rel)
# Out:
# Accuracy: 0.32087227414330216
# F1 Score: 0.32204163987749085
# Precision: 0.34334031095009204
# Recall: 0.32087227414330216

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
cm = confusion_matrix(y1,y_test)
cm
# Out:
# array([[26, 26, 24, 32],
#        [19, 26, 17, 25],
#        [ 6,  4, 14,  4],
#        [22, 21, 18, 37]], dtype=int64)

# %%
cmd = ConfusionMatrixDisplay(cm)
cmd.plot()
plt.show()

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y2 = gnb.predict(x_test)

# %%
from sklearn.metrics import f1_score, recall_score, precision_score, accuracy_score
acc = accuracy_score(y2, y_test)
f1 = f1_score(y2, y_test, average='weighted')
pre = precision_score(y2, y_test, average='weighted')
rel = recall_score(y2, y_test, average='weighted')
print('Accuracy:', acc)
print('F1 Score:', f1)
print('Precision:', pre)
print('Recall:', rel)
# Out:
# Accuracy: 0.30218068535825543
# F1 Score: 0.2987614235275458
# Precision: 0.30430599632457817
# Recall: 0.30218068535825543

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
cm1 = confusion_matrix(y2,y_test)
cm1
# Out:
# array([[25, 27, 17, 31],
#        [20, 20, 22, 24],
#        [14,  9, 23, 14],
#        [14, 21, 11, 29]], dtype=int64)

# %%
cmd1 = ConfusionMatrixDisplay(cm1)
cmd1.plot()
plt.show()

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y3 = knn.predict(x_test)

# %%
from sklearn.metrics import f1_score, recall_score, precision_score, accuracy_score
acc = accuracy_score(y3, y_test)
f1 = f1_score(y3, y_test, average='weighted')
pre = precision_score(y3, y_test, average='weighted')
rel = recall_score(y3, y_test, average='weighted')
print('Accuracy:', acc)
print('F1 Score:', f1)
print('Precision:', pre)
print('Recall:', rel)
# Out:
# Accuracy: 0.5389408099688473
# F1 Score: 0.5388317982511123
# Precision: 0.554401975173049
# Recall: 0.5389408099688473

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
cm2 = confusion_matrix(y3,y_test)
cm2
# Out:
# array([[47, 18, 19, 19],
#        [ 9, 42, 15, 14],
#        [ 7,  7, 31, 12],
#        [10, 10,  8, 53]], dtype=int64)

# %%
cmd2 = ConfusionMatrixDisplay(cm2)
cmd2.plot()
plt.show()

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC
svc = SVC(kernel = 'rbf', C=1000,gamma=0.01)
svc.fit(x_train,y_train)
# Out:
# SVC(C=1000, gamma=0.01)

# %%
y4 = svc.predict(x_test)

# %%
from sklearn.metrics import f1_score, recall_score, precision_score, accuracy_score
acc = accuracy_score(y4, y_test)
f1 = f1_score(y4, y_test, average='weighted')
pre = precision_score(y4, y_test, average='weighted')
rel = recall_score(y4, y_test, average='weighted')
print('Accuracy:', acc)
print('F1 Score:', f1)
print('Precision:', pre)
print('Recall:', rel)
# Out:
# Accuracy: 0.6728971962616822
# F1 Score: 0.6715971361805719
# Precision: 0.679563817007349
# Recall: 0.6728971962616822

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
cm4 = confusion_matrix(y4,y_test)
cm4
# Out:
# array([[52, 14, 20,  8],
#        [ 8, 48,  6, 11],
#        [ 3,  6, 43,  6],
#        [10,  9,  4, 73]], dtype=int64)

# %%
cmd4 = ConfusionMatrixDisplay(cm3)
cmd4.plot()
plt.show()
